# %% [markdown]
# ## ORIGINALKOD

# %% [markdown]
# ### Här börjar vi skriva koden:

# %% [markdown]
# #### *AMB modell*:

# %% [markdown]
# #### *Runna ABM modell*:

# %% [markdown]
# #### *Plotta ABM modell*:

# %%
print("hej")
# Out:
# hej
